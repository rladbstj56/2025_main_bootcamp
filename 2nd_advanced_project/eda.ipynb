# %%
# 데이터 처리 및 분석
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import warnings

# 시각화
import matplotlib.pyplot as plt
import seaborn as sns

# 통계 분석
from scipy import stats
from scipy.stats import shapiro, levene, ttest_ind, chi2_contingency, f_oneway
from scipy.stats import mannwhitneyu, fisher_exact, kruskal
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison
import pingouin as pg
import scikit_posthocs as sp

# 출력 설정
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# 한글 폰트 설정
import platform
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':  # macOS
    plt.rcParams['font.family'] = 'AppleGothic'
else:  # Linux
    plt.rcParams['font.family'] = 'NanumGothic'

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (12, 6)

# 시드 설정
np.random.seed(42)

print("="*60)
print("라이브러리 로드 완료!")
print("한글 폰트 설정 완료!")
print("="*60)
# Out:
# ============================================================
# 라이브러리 로드 완료!
# 한글 폰트 설정 완료!
# ============================================================

# %%
df = pd.read_csv('./data/merged_data.csv')

# %%
df[df['total_item_count']>1]
# Out:
#                                order_id                       customer_id  \
# 10     e6ce16cb79ec1d90b1da9085a6118aeb  494dded5b201313c64ed7f100595b95c
# 26     acce194856392f074dbf9dada14d8d82  7e20bf5ca92da68200643bda76c504c6
# 52     9faeb9b2746b9d7526aef5acb08e2aa0  79183cd650e2bb0d475b0067d45946ac
# 57     66e4624ae69e7dc89bd50222b59f581f  684fa6da5134b9e4dab731e00011712d
# 64     688052146432ef8253587b930b01a06d  81e08b08e5ed4472008030d70327c71f
# ...                                 ...                               ...
# 99366  83db27f85506380229913b0dfdf5cd18  472acc24324ad4cee482fe4ef5910dc1
# 99373  b3112ca67f3afd4e20cf2ee91fc4f804  6f83c71b6c044fb156d697d4130fe9b5
# 99391  e8fd20068b9f7e6ec07068bb7537f781  609b9fb8cad4fe0c7b376f77c8ab76ad
# 99410  9115830be804184b91f5c00f6f49f92d  da2124f134f5dfbce9d06f29bdb6c308
# 99416  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 10       delivered      2017-05-16 19:41:10  2017-05-16 19:50:18
# 26       delivered      2018-06-04 00:00:13  2018-06-05 00:35:10
# 52       delivered      2018-07-26 14:39:59  2018-07-26 14:55:10
# 57       delivered      2018-03-09 14:50:15  2018-03-09 15:40:39
# 64       delivered      2018-04-22 08:48:13  2018-04-24 18:25:22
# ...            ...                      ...                  ...
# 99366    delivered      2018-04-18 12:35:58  2018-04-19 02:51:26
# 99373    delivered      2018-08-02 22:46:54  2018-08-02 23:04:06
# 99391    delivered      2017-08-10 21:21:07  2017-08-10 21:35:26
# 99410    delivered      2017-10-04 19:57:37  2017-10-04 20:07:14
# 99416    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 10             2017-05-18 11:40:40           2017-05-29 11:18:31
# 26             2018-06-05 13:24:00           2018-06-16 15:20:55
# 52             2018-07-27 12:04:00           2018-07-31 22:26:55
# 57             2018-03-15 00:31:19           2018-04-03 13:28:46
# 64             2018-04-23 19:19:14           2018-04-24 19:31:58
# ...                            ...                           ...
# 99366          2018-05-02 08:52:00           2018-05-07 16:40:55
# 99373          2018-08-15 17:42:00           2018-08-21 00:03:26
# 99391          2017-08-18 16:42:51           2017-08-23 15:36:29
# 99410          2017-10-05 16:52:52           2017-10-20 20:25:45
# 99416          2018-01-12 15:35:03           2018-01-25 23:32:54
#
#       order_estimated_delivery_date                customer_unique_id  \
# 10                       2017-06-07  f2a85dec752b8517b5e58a06ff3cd937
# 26                       2018-07-18  576ea0cab426cd8a00fad9a9c90a4494
# 52                       2018-08-16  c77154776ead8e798c2d684205938f71
# 57                       2018-04-02  ddf60e20e6e262e2136801ce5cd628b0
# 64                       2018-05-15  0e764fc1a13e47e900c3d59a989753e8
# ...                             ...                               ...
# 99366                    2018-05-29  35a382f91046bec8ef1acb7dc62b7318
# 99373                    2018-08-16  f690f0caffab80b6f849f08ba1692925
# 99391                    2017-08-31  fb9310710003399b031add3e55f34719
# 99410                    2017-11-07  c716cf2b5b86fb24257cffe9e7969df8
# 99416                    2018-02-15  5097a5312c8b157bb7be58ae360ef43c
#
#        customer_zip_code_prefix   customer_city customer_state  \
# 10                        20780  rio de janeiro             RJ
# 26                        41213        salvador             BA
# 52                        90620    porto alegre             RS
# 57                        49030         aracaju             SE
# 64                        36045    juiz de fora             MG
# ...                         ...             ...            ...
# 99366                     21931  rio de janeiro             RJ
# 99373                      9330            maua             SP
# 99391                      3318       sao paulo             SP
# 99410                     78048          cuiaba             MT
# 99416                     28685         japuiba             RJ
#
#        geolocation_zip_code_prefix_x  geolocation_lat_x  geolocation_lng_x  \
# 10                           20780.0         -22.897213         -43.273353
# 26                           41213.0         -12.937378         -38.446331
# 52                           90620.0         -30.050351         -51.201288
# 57                           49030.0         -10.971960         -37.067901
# 64                           36045.0         -21.741527         -43.359353
# ...                              ...                ...                ...
# 99366                        21931.0         -22.810297         -43.199729
# 99373                         9330.0         -23.662719         -46.421803
# 99391                         3318.0         -23.544485         -46.565692
# 99410                        78048.0         -15.572513         -56.084154
# 99416                        28685.0         -22.563909         -42.695343
#
#        total_item_count                                         product_id  \
# 10                  2.0  <StringArray>\n['08574b074924071f4e201e151b152...
# 26                  2.0  <StringArray>\n['d70f38e7f79c630f8ea00c9938970...
# 52                  2.0  <StringArray>\n['f48eb5c2fde13ca63664f0bb05f55...
# 57                  2.0  <StringArray>\n['b37b72d5a56f887725c2862184b8c...
# 64                  2.0  <StringArray>\n['d1c427060a0f73f6b889a5c7c61f2...
# ...                 ...                                                ...
# 99366               2.0  <StringArray>\n['86f2416d4670e4ea3ca5494d043d9...
# 99373               2.0  <StringArray>\n['4f18ca9862f511ecba98258b2194d...
# 99391               2.0  <StringArray>\n['0df37da38a30a713453b03053d60d...
# 99410               2.0  <StringArray>\n['c982dbea53b864f4d27c1d36f14b6...
# 99416               2.0  <StringArray>\n['d1c427060a0f73f6b889a5c7c61f2...
#
#                                                seller_id  \
# 10     <StringArray>\n['001cca7ae9ae17fb1caed9dfb1094...
# 26     <StringArray>\n['977f9f63dd360c2a32ece2f93ad6d...
# 52     <StringArray>\n['f7ba60f8c3f99e7ee4042fdef03b7...
# 57     <StringArray>\n['db4350fd57ae30082dec7acbaacc1...
# 64     <StringArray>\n['a1043bafd471dff536d0c462352be...
# ...                                                  ...
# 99366  <StringArray>\n['7c67e1448b00f6e969d365cea6b01...
# 99373  <StringArray>\n['5b0cc932433fa5184b5b94bfe6bcc...
# 99391  <StringArray>\n['218d46b86c1881d022bce9c68a7d4...
# 99410  <StringArray>\n['1caf283236cd69af44cbc09a0a1e7...
# 99416  <StringArray>\n['a1043bafd471dff536d0c462352be...
#
#                                      shipping_limit_date  total_price  \
# 10     <DatetimeArray>\n['2017-05-22 19:50:18', '2017...       198.00
# 26     <DatetimeArray>\n['2018-06-13 00:35:10', '2018...       130.40
# 52     <DatetimeArray>\n['2018-07-30 14:55:10', '2018...       120.00
# 57     <DatetimeArray>\n['2018-03-15 15:30:45', '2018...        45.98
# 64     <DatetimeArray>\n['2018-04-26 09:31:11', '2018...       318.00
# ...                                                  ...          ...
# 99366  <DatetimeArray>\n['2018-05-04 02:51:26', '2018...       299.88
# 99373  <DatetimeArray>\n['2018-08-08 23:04:06', '2018...       190.00
# 99391  <DatetimeArray>\n['2017-08-17 21:35:26', '2017...       712.00
# 99410  <DatetimeArray>\n['2017-10-10 20:07:14', '2017...        69.01
# 99416  <DatetimeArray>\n['2018-01-12 21:36:21', '2018...       359.98
#
#        total_freight  total_weight_g product_length_cm product_height_cm  \
# 10             61.06         18000.0         [42. 42.]         [12. 12.]
# 26             97.28         11300.0         [41. 31.]         [40. 10.]
# 52             31.04           200.0         [20. 20.]         [11. 11.]
# 57             45.70           300.0         [19. 19.]           [4. 4.]
# 64             28.09         19000.0         [20. 40.]         [20. 25.]
# ...              ...             ...               ...               ...
# 99366          98.30         23400.0         [36. 36.]         [54. 54.]
# 99373          49.50         25000.0         [43. 43.]         [33. 33.]
# 99391          36.24          5600.0         [28. 28.]         [23. 23.]
# 99410          37.78          1350.0         [48. 26.]         [10. 15.]
# 99416          81.18         13100.0         [20. 20.]         [20. 20.]
#
#       product_width_cm                                           category  \
# 10           [39. 39.]  <StringArray>\n['garden_tools', 'garden_tools'...
# 26           [40. 12.]  <StringArray>\n['baby', 'baby']\nLength: 2, dt...
# 52           [11. 11.]  <StringArray>\n['sports_leisure', 'sports_leis...
# 57           [11. 11.]  <StringArray>\n['telephony', 'telephony']\nLen...
# 64           [20. 57.]  <StringArray>\n['computers_accessories', 'lugg...
# ...                ...                                                ...
# 99366        [35. 35.]  <StringArray>\n['office_furniture', 'office_fu...
# 99373        [33. 33.]  <StringArray>\n['furniture_bedroom', 'furnitur...
# 99391        [23. 23.]  <StringArray>\n['sports_leisure', 'sports_leis...
# 99410        [48. 26.]  <StringArray>\n['toys', 'toys']\nLength: 2, dt...
# 99416        [20. 20.]  <StringArray>\n['computers_accessories', 'comp...
#
#                                   seller_zip_code_prefix  \
# 10     <StringArray>\n['29156', '29156']\nLength: 2, ...
# 26     <StringArray>\n['14910', '14940']\nLength: 2, ...
# 52     <StringArray>\n['9628', '9628']\nLength: 2, dt...
# 57     <StringArray>\n['3126', '3126']\nLength: 2, dt...
# 64     <StringArray>\n['37175', '30111']\nLength: 2, ...
# ...                                                  ...
# 99366  <StringArray>\n['8577', '8577']\nLength: 2, dt...
# 99373  <StringArray>\n['14940', '14940']\nLength: 2, ...
# 99391  <StringArray>\n['14070', '14070']\nLength: 2, ...
# 99410  <StringArray>\n['26020', '26020']\nLength: 2, ...
# 99416  <StringArray>\n['37175', '37175']\nLength: 2, ...
#
#                                              seller_city  \
# 10     <StringArray>\n['cariacica', 'cariacica']\nLen...
# 26     <StringArray>\n['tabatinga', 'ibitinga']\nLeng...
# 52     <StringArray>\n['sao bernardo do campo', 'sao ...
# 57     <StringArray>\n['sao paulo', 'sao paulo']\nLen...
# 64     <StringArray>\n['ilicinea', 'belo horizonte']\...
# ...                                                  ...
# 99366  <StringArray>\n['itaquaquecetuba', 'itaquaquec...
# 99373  <StringArray>\n['ibitinga', 'ibitinga']\nLengt...
# 99391  <StringArray>\n['ribeirao preto', 'ribeirao pr...
# 99410  <StringArray>\n['nova iguacu', 'nova iguacu']\...
# 99416  <StringArray>\n['ilicinea', 'ilicinea']\nLengt...
#
#                                             seller_state  \
# 10     <StringArray>\n['ES', 'ES']\nLength: 2, dtype:...
# 26     <StringArray>\n['SP', 'SP']\nLength: 2, dtype:...
# 52     <StringArray>\n['SP', 'SP']\nLength: 2, dtype:...
# 57     <StringArray>\n['SP', 'SP']\nLength: 2, dtype:...
# 64     <StringArray>\n['MG', 'MG']\nLength: 2, dtype:...
# ...                                                  ...
# 99366  <StringArray>\n['SP', 'SP']\nLength: 2, dtype:...
# 99373  <StringArray>\n['SP', 'SP']\nLength: 2, dtype:...
# 99391  <StringArray>\n['SP', 'SP']\nLength: 2, dtype:...
# 99410  <StringArray>\n['RJ', 'RJ']\nLength: 2, dtype:...
# 99416  <StringArray>\n['MG', 'MG']\nLength: 2, dtype:...
#
#                            geolocation_zip_code_prefix_y  \
# 10     <StringArray>\n['29156', '29156']\nLength: 2, ...
# 26     <StringArray>\n['14910', '14940']\nLength: 2, ...
# 52     <StringArray>\n['9628', '9628']\nLength: 2, dt...
# 57     <StringArray>\n['3126', '3126']\nLength: 2, dt...
# 64     <StringArray>\n['37175', '30111']\nLength: 2, ...
# ...                                                  ...
# 99366  <StringArray>\n['8577', '8577']\nLength: 2, dt...
# 99373  <StringArray>\n['14940', '14940']\nLength: 2, ...
# 99391  <StringArray>\n['14070', '14070']\nLength: 2, ...
# 99410  <StringArray>\n['26020', '26020']\nLength: 2, ...
# 99416  <StringArray>\n['37175', '37175']\nLength: 2, ...
#
#                  geolocation_lat_y            geolocation_lng_y  \
# 10     [-20.27922392 -20.27922392]  [-40.41151357 -40.41151357]
# 26     [-21.73706335 -21.75722511]  [-48.68756877 -48.82954114]
# 52       [-23.6612683 -23.6612683]  [-46.56432334 -46.56432334]
# 57     [-23.58051381 -23.58051381]  [-46.59091779 -46.59091779]
# 64     [-20.94071153 -19.91916214]  [-45.82719542 -43.94431129]
# ...                            ...                          ...
# 99366  [-23.48613766 -23.48613766]  [-46.36710748 -46.36710748]
# 99373  [-21.75722511 -21.75722511]  [-48.82954114 -48.82954114]
# 99391      [-21.113399 -21.113399]    [-47.7909767 -47.7909767]
# 99410    [-22.7324094 -22.7324094]      [-43.449801 -43.449801]
# 99416  [-20.94071153 -20.94071153]  [-45.82719542 -45.82719542]
#
#        mean_review_score  review_count order_purchase_dayofweek  \
# 10                   1.0           1.0                  tuesday
# 26                   1.0           1.0                   monday
# 52                   1.0           1.0                 thursday
# 57                   1.0           1.0                   friday
# 64                   4.0           1.0                   sunday
# ...                  ...           ...                      ...
# 99366                5.0           1.0                wednesday
# 99373                2.0           1.0                 thursday
# 99391                4.0           1.0                 thursday
# 99410                5.0           1.0                wednesday
# 99416                2.0           1.0                   monday
#
#        order_purchase_month  order_purchase_year
# 10                        5                 2017
# 26                        6                 2018
# 52                        7                 2018
# 57                        3                 2018
# 64                        4                 2018
# ...                     ...                  ...
# 99366                     4                 2018
# 99373                     8                 2018
# 99391                     8                 2017
# 99410                    10                 2017
# 99416                     1                 2018
#
# [9783 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99418 entries, 0 to 99417
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99418 non-null  str
#  1   customer_id                    99418 non-null  str
#  2   order_status                   99418 non-null  str
#  3   order_purchase_timestamp       99418 non-null  str
#  4   order_approved_at              99258 non-null  str
#  5   order_delivered_carrier_date   97635 non-null  str
#  6   order_delivered_customer_date  96453 non-null  str
#  7   order_estimated_delivery_date  99418 non-null  str
#  8   customer_unique_id             99418 non-null  str
#  9   customer_zip_code_prefix       99418 non-null  int64
#  10  customer_city                  99418 non-null  str
#  11  customer_state                 99418 non-null  str
#  12  geolocation_zip_code_prefix_x  99140 non-null  float64
#  13  geolocation_lat_x              99140 non-null  float64
#  14  geolocation_lng_x              99140 non-null  float64
#  15  total_item_count               98643 non-null  float64
#  16  product_id                     98643 non-null  str
#  17  seller_id                      98643 non-null  str
#  18  shipping_limit_date            98643 non-null  str
#  19  total_price                    98643 non-null  float64
#  20  total_freight                  98643 non-null  float64
#  21  total_weight_g                 98643 non-null  float64
#  22  product_length_cm              98629 non-null  str
#  23  product_height_cm              98629 non-null  str
#  24  product_width_cm               98629 non-null  str
#  25  category                       97337 non-null  str
#  26  seller_zip_code_prefix         98643 non-null  str
#  27  seller_city                    98643 non-null  str
#  28  seller_state                   98643 non-null  str
#  29  geolocation_zip_code_prefix_y  98453 non-null  str
#  30  geolocation_lat_y              98453 non-null  str
#  31  geolocation_lng_y              98453 non-null  str
#  32  mean_review_score              98650 non-null  float64
#  33  review_count                   98650 non-null  float64
#  34  order_purchase_dayofweek       99418 non-null  str
#  35  order_purchase_month           99418 non-null  int64
#  36  order_purchase_year            99418 non-null  int64
# dtypes: float64(9), int64(3), str(25)
# memory usage: 28.1 MB

# %%
df2 = df.copy()
