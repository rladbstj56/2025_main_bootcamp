# %%
# 1.
import pandas as pd

customers = pd.read_csv("bootcamp_customers.csv", encoding='utf-8')
orders = pd.read_csv("bootcamp_orders.csv", encoding='utf-8')

print(customers.shape)
print(orders.shape)

# 2. 
dup_cnt = orders.duplicated().sum()
print(f"dup order_id count: {dup_cnt}")

# 3. 
print("customers missing: ")
print(customers.isna().sum())
print("\n")
print("orders missing: ")
print(orders.isna().sum())
# Out:
# (12, 6)
# (31, 10)
# dup order_id count: 1
# customers missing:
# customer_id      0
# customer_name    0
# age              1
# city             1
# signup_date      0
# segment          0
# dtype: int64
#
#
# orders missing:
# order_id          0
# order_date        0
# customer_id       0
# product           0
# category          0
# unit_price        0
# quantity          0
# discount_rate     2
# payment_method    0
# rating            1
# dtype: int64
